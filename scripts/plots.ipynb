# %%
import pandas as pd

# %%
pan = ['Eukaryotes;Animals;Mammals;Primates']
oro = ['Eukaryotes;Animals;Mammals;Carnivora']
scam = ['Eukaryotes;Animals;Birds;Palaeognathae']
thas = ['Prokaryotes;Bacteria;Alphaproteobacteria;Pukyongiella']
war = ['Prokaryotes;Archaea;Woesearchaeota;unclassified Woesearchaeota']
data = list(zip(pan, oro, scam, thas, war))
df = pd.DataFrame(data, columns=['pan', 'oro', 'scam', 'thas', 'war']).T

# %%
df
# Out:
#                                                       0
# pan                 Eukaryotes;Animals;Mammals;Primates
# oro                Eukaryotes;Animals;Mammals;Carnivora
# scam             Eukaryotes;Animals;Birds;Palaeognathae
# thas  Prokaryotes;Bacteria;Alphaproteobacteria;Pukyo...
# war   Prokaryotes;Archaea;Woesearchaeota;unclassifie...

# %%
data
# Out:
# [('Eukaryotes;Animals;Mammals;Primates',
#   'Eukaryotes;Animals;Mammals;Carnivora',
#   'Eukaryotes;Animals;Birds;Palaeognathae',
#   'Prokaryotes;Bacteria;Alphaproteobacteria;Pukyongiella',
#   'Prokaryotes;Archaea;Woesearchaeota;unclassified Woesearchaeota')]
